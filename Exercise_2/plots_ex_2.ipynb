# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Data and Plot for 1a
data_1_a = np.loadtxt('ex_2_1_a.txt', delimiter=',')
plt.loglog(data_1_a[:,0],data_1_a[:,1])
# Out:
# [1.00e+06 2.00e+06 4.00e+06 8.00e+06 1.60e+07 3.20e+07 6.40e+07 1.28e+08]

# %%
#Data and Plot for 1b 0+1
data_1_b1 = np.loadtxt('ex_2_1_b1.txt', delimiter=',')
data_1_b2 = np.loadtxt('ex_2_1_b2.txt', delimiter=',')
plt.loglog(data_1_b1[:,0],data_1_b1[:,1])
plt.loglog(data_1_b2[:,0],data_1_b2[:,1])
