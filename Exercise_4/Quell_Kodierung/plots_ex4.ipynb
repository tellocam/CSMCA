# %%
import matplotlib.pyplot as plt
import numpy as np
from pylab import rcParams
rcParams['figure.figsize'] = 10, 7

plt.rc('text', usetex=True)
plt.rcParams['text.usetex']=True

plt.rc('font', family='sans-serif', weight='bold')

SMALL_SIZE = 20
MEDIUM_SIZE = 20
BIGGER_SIZE = 25

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)    # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rcParams['figure.dpi'] = 500

# %%
coding_on_camilos_laptop = True
figures_path = '/home/tellocam/CSE/CSMCA/Exercise_4/latex_ex_4/figures'

k8 = np.loadtxt('k8.txt', delimiter=',')
k16 = np.loadtxt('k16.txt', delimiter=',')
k24 = np.loadtxt('k24.txt', delimiter=',')
k32 = np.loadtxt('k32.txt', delimiter=',')

# %%
plt.figure(1)
plt.title('Execution times - Task 2c')
plt.loglog(k8[:,0],k8[:,2], color='red', linewidth=2, label='$\mathrm{K}=8$')
plt.loglog(k16[:,0],k16[:,2], color='green', linewidth=2, label='$\mathrm{K}=16$')
plt.loglog(k24[:,0],k24[:,2], color='blue', linewidth=2, label='$\mathrm{K}=24$')
plt.loglog(k32[:,0],k32[:,2], color='magenta', linewidth=2, label='$\mathrm{K}=32$')
#plt.semilogy(data_1_a_2[:,0],data_1_a_2[:,1], color='blue', linewidth=2, label='Effective Bandwidth on RTX3060')
plt.grid(True, which="both")
plt.xlabel('$\mathrm{N}$ / -')
plt.ylabel('$t_{\mathrm{exec}} / \mathrm{s}$')
plt.legend()
plt.tight_layout()
if(coding_on_camilos_laptop==True):
    plt.savefig(figures_path + '/task_2_c.pdf')
